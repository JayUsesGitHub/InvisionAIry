# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import warnings
import json

# Suppress warnings
warnings.filterwarnings('ignore')

# TensorFlow and Keras libraries for image processing and model training
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import plot_model
from tensorflow.keras import backend
from sklearn.metrics import confusion_matrix, classification_report

# SHAP for model explainability
import shap
from operator import itemgetter

# Holoviews for interactive plots (optional, depending on your needs)
import holoviews as hv
from holoviews import opts
hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='7d9bdf88-6fee-46a9-86f0-3f1a0b51608e'>
#   <div id="f3e2958e-5318-4232-b5dc-ddb7fedc1e7f" data-root-id="7d9bdf88-6fee-46a9-86f0-3f1a0b51608e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Specify data directory
data_dir = "Mechanical Quality Assurance"
my_data_dir = f'{data_dir}/real-life-industrial-dataset-of-casting-product/casting_data/casting_data/'

# %%
# Define train and test paths
train_path = os.path.join(my_data_dir, 'train')
test_path = os.path.join(my_data_dir, 'test')

# %%
# Visualize an example of 'ok' and 'def' images from the training dataset
plt.figure(figsize=(12, 6))

# %%
# Displaying 'ok' image
ok_image_path = os.path.join(train_path, 'ok_front/cast_ok_0_1.jpeg')
ok = plt.imread(ok_image_path)
plt.subplot(1, 2, 1)
plt.axis('off')
plt.title("OK (Normal)", weight='bold', size=16)
plt.imshow(ok, cmap='gray')

# %%
# Displaying 'def' image
ng_image_path = os.path.join(train_path, 'def_front/cast_def_0_1001.jpeg')
ng = plt.imread(ng_image_path)
plt.subplot(1, 2, 2)
plt.axis('off')
plt.title("Defective", weight='bold', size=16)
plt.imshow(ng, cmap='gray')

# %%
plt.show()
